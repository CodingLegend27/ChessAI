# %%
#Importing Packages
import os
import tensorflow as tf
print("Version of tensorflow:", tf.__version__)
import numpy as np
import gym
import gym_chess
# Out:
# Version of tensorflow: 1.14.0
# ERROR: File "setup.py" not found. Directory cannot be installed in editable mode: /home/thelegend27/Schreibtisch/repos/ChessAI
# /home/thelegend27/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env = gym.make('ChessVsSelf-v0')
env.reset()
state = env.state

moves_p1 = env.get_possible_moves(state, 1)
moves_p2 = env.get_possible_moves(state, -1)
print(moves_p1)
print("\n", moves_p2)

print("Player 1:")
for m in moves_p1:
    print(env.convert_coords(m))

print("\nPlayer2")
for m in moves_p2:
    print(env.convert_coords(m))

# Player 1 moves
for piece in set([m['piece_id'] for m in moves_p1]):
    env.render_moves(state, piece, moves_p1, mode='human')

# Player 2 moves
for piece in set([m['piece_id'] for m in moves_p2]):
    env.render_moves(state, piece, moves_p2, mode='human')



import random

# moves
# Out:
# [{'piece_id': 1, 'pos': (0, 0), 'new_pos': array([0, 1]), 'type': 'move'}, {'piece_id': 1, 'pos': (0, 0), 'new_pos': array([0, 2]), 'type': 'move'}, {'piece_id': 5, 'pos': (0, 3), 'new_pos': array([1, 3]), 'type': 'move'}, {'piece_id': 5, 'pos': (0, 3), 'new_pos': array([0, 4]), 'type': 'move'}, {'piece_id': 5, 'pos': (0, 3), 'new_pos': array([0, 2]), 'type': 'move'}, {'piece_id': 5, 'pos': (0, 3), 'new_pos': array([1, 4]), 'type': 'move'}, {'piece_id': 5, 'pos': (0, 3), 'new_pos': array([1, 2]), 'type': 'move'}, {'piece_id': 8, 'pos': (0, 7), 'new_pos': array([0, 6]), 'type': 'move'}, {'piece_id': 8, 'pos': (0, 7), 'new_pos': array([0, 5]), 'type': 'move'}, {'piece_id': 8, 'pos': (0, 7), 'new_pos': array([0, 4]), 'type': 'move'}, {'piece_id': 9, 'pos': (1, 0), 'new_pos': array([2, 0]), 'type': 'move'}, {'piece_id': 9, 'pos': (1, 0), 'new_pos': array([3, 0]), 'type': 'move'}, {'piece_id': 16, 'pos': (1, 7), 'new_pos': array([2, 7]), 'type': 'move'}, {'piece_id': 16, 'pos': (1, 7), 'new_pos': array([3, 7]), 'type': 'move'}, {'piece_id': 20, 'pos': None, 'new_pos': [0, 5], 'type': 'castling', 'castle': 2}, {'piece_id': 20, 'pos': None, 'new_pos': [0, 1], 'type': 'castling', 'castle': 1}]
#
#  [{'piece_id': -9, 'pos': (6, 0), 'new_pos': array([5, 0]), 'type': 'move'}, {'piece_id': -9, 'pos': (6, 0), 'new_pos': array([4, 0]), 'type': 'move'}, {'piece_id': -16, 'pos': (6, 7), 'new_pos': array([5, 7]), 'type': 'move'}, {'piece_id': -16, 'pos': (6, 7), 'new_pos': array([4, 7]), 'type': 'move'}, {'piece_id': -1, 'pos': (7, 0), 'new_pos': array([7, 1]), 'type': 'move'}, {'piece_id': -1, 'pos': (7, 0), 'new_pos': array([7, 2]), 'type': 'move'}, {'piece_id': -5, 'pos': (7, 3), 'new_pos': array([6, 3]), 'type': 'move'}, {'piece_id': -5, 'pos': (7, 3), 'new_pos': array([7, 4]), 'type': 'move'}, {'piece_id': -5, 'pos': (7, 3), 'new_pos': array([7, 2]), 'type': 'move'}, {'piece_id': -5, 'pos': (7, 3), 'new_pos': array([6, 4]), 'type': 'move'}, {'piece_id': -5, 'pos': (7, 3), 'new_pos': array([6, 2]), 'type': 'move'}, {'piece_id': -8, 'pos': (7, 7), 'new_pos': array([7, 6]), 'type': 'move'}, {'piece_id': -8, 'pos': (7, 7), 'new_pos': array([7, 5]), 'type': 'move'}, {'piece_id': -8, 'pos': (7, 7), 'new_pos': array([7, 4]), 'type': 'move'}, {'piece_id': -20, 'pos': None, 'new_pos': [7, 5], 'type': 'castling', 'castle': 2}, {'piece_id': -20, 'pos': None, 'new_pos': [7, 1], 'type': 'castling', 'castle': 1}]
# Player 1:
# Ra1-b1
# Ra1-c1
# Kd1-d2
# Kd1-e1
# Kd1-c1
# Kd1-e2
# Kd1-c2
# Rh1-g1
# Rh1-f1
# Rh1-e1
# a2-a3
# a2-a4
# h2-h3
# h2-h4
# 0-0-0
# 0-0
#
# Player2
# a7-a6
# a7-a5
# h7-h6
# h7-h5
# Ra8-b8
# Ra8-c8
# Kd8-d7
# Kd8-e8
# Kd8-c8
# Kd8-e7
# Kd8-c7
# Rh8-g8
# Rh8-f8
# Rh8-e8
# 0-0-0
# 0-0
#     -------------------------
#  8 |  ♖  .  .  .  ♔  .  .  ♖ |
#  7 |  ♙  .  .  .  .  .  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  .  .  .  .  ♟ |
#  1 |  ♜  .  .  .  ♚  X  X <♜>|
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  .  .  ♔  .  .  ♖ |
#  7 |  ♙  .  .  .  .  .  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  X  X  X  .  ♟ |
#  1 |  ♜  .  .  X <♚> X  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  .  .  ♔  .  .  ♖ |
#  7 |  ♙  .  .  .  .  .  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  .  .  .  .  ♟ |
#  1 | <♜> X  X  X  ♚  .  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  .  .  ♔  .  .  ♖ |
#  7 |  ♙  .  .  .  .  .  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  X |
#  3 |  .  .  .  .  .  .  .  X |
#  2 |  ♟  .  .  .  .  .  . <♟>|
#  1 |  ♜  .  .  .  ♚  .  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  .  .  ♔  .  .  ♖ |
#  7 |  ♙  .  .  .  .  .  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  X  .  .  .  .  .  .  . |
#  3 |  X  .  .  .  .  .  .  . |
#  2 | <♟> .  .  .  .  .  .  ♟ |
#  1 |  ♜  .  .  .  ♚  .  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  .  .  ♔  .  .  ♖ |
#  7 |  ♙  .  .  .  .  .  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  .  .  .  .  ♟ |
#  1 |  ♜  . 0-0 .  ♚  . 0-0 ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  X  .  ♔  .  X  ♖ |
#  7 |  ♙  .  .  .  .  .  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  .  .  .  .  ♟ |
#  1 |  ♜  .  .  .  ♚  .  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  .  .  ♔  .  .  ♖ |
#  7 | <♙> .  .  .  .  .  .  ♙ |
#  6 |  X  .  .  .  .  .  .  . |
#  5 |  X  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  .  .  .  .  ♟ |
#  1 |  ♜  .  .  .  ♚  .  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  .  .  ♔  .  .  ♖ |
#  7 |  ♙  .  .  .  .  .  . <♙>|
#  6 |  .  .  .  .  .  .  .  X |
#  5 |  .  .  .  .  .  .  .  X |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  .  .  .  .  ♟ |
#  1 |  ♜  .  .  .  ♚  .  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 | <♖> X  X  X  ♔  .  .  ♖ |
#  7 |  ♙  .  .  .  .  .  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  .  .  .  .  ♟ |
#  1 |  ♜  .  .  .  ♚  .  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  .  X <♔> X  .  ♖ |
#  7 |  ♙  .  .  X  X  X  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  .  .  .  .  ♟ |
#  1 |  ♜  .  .  .  ♚  .  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
#
#     -------------------------
#  8 |  ♖  .  .  .  ♔  X  X <♖>|
#  7 |  ♙  .  .  .  .  .  .  ♙ |
#  6 |  .  .  .  .  .  .  .  . |
#  5 |  .  .  .  .  .  .  .  . |
#  4 |  .  .  .  .  .  .  .  . |
#  3 |  .  .  .  .  .  .  .  . |
#  2 |  ♟  .  .  .  .  .  .  ♟ |
#  1 |  ♜  .  .  .  ♚  .  .  ♜ |
#     -------------------------
#       a  b  c  d  e  f  g  h
